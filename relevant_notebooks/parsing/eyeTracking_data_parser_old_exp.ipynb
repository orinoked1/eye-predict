# %%
import numpy as np
import pandas as pd
import codecs
import os
import glob

# %% [markdown]
# # Data Parsing to DF
# ## Parsing time, takes about 1-3 minuets per file/subject
# ### Fill in the relvant STR for directory, indexStartStr, indexEndStr variables according to your local environment

# %%
trialCount
# Out:
# 0

# %%
flag = 0
# Set directory name that contains output directory with asc and txt files
directory = '..//mri_faces_data//Output'
# Set string represents trail start data records
indexStartStr = ', StimLeft:'  #'TrialStart'
# Set string represents trail ends data records
indexEndStr = 'Fixation'   #'ScaleStart'

#Run over each Ascii file and open it
for ascFile in glob.glob(directory +'//*asc'):
    ascFileName = os.path.basename(ascFile)
    tempList = ascFileName.split('_')
    subjectIntId = tempList[2]
    print('Log.....Getting Ascii file data - ' + ascFileName)
    ascFile = codecs.open(directory + '//' + ascFileName, encoding='utf-8-sig')

    ascData = ascFile.readlines()
    #Split data to columns and get only relevnt ones
    ascDf = pd.DataFrame(ascData,columns = ['data'])
    ascDf = ascDf['data'].apply(lambda x: pd.Series(x.split('\t')))
    ascDf = ascDf[[0,1,2]]
    print('Log.....Getting txt file data for subject id - ' + subjectIntId)
    
    #Read txt file of subject same subject as asc file
    txtFileName = os.path.basename(glob.glob(directory + '//*' + subjectIntId + '*txt')[0])
    txtData = pd.read_table(directory + '//' + txtFileName)
    # Get number of trials and subject ID
    trialCount = txtData.count()[0]
    #subjectId = txtData['subjectID'][0]
    print('Log.....Runing over all trials of subject id - '+subjectIntId)
    # Run over all trials per user and merge the asc data with the txt data
    for trial in range(trialCount):
        trial_str = 'trial: ' + str(trial+1).zfill(0)
        indexStart = ascDf[ascDf[1].str.contains(indexStartStr, na=False) & 
                                            ascDf[1].str.contains(trial_str, na=False)].index[0]+1
        indexEnd = ascDf[ascDf[1].str.contains(indexEndStr, na=False) & 
                                          ascDf[1].str.contains(trial_str, na=False)].index[0]-1
        #Get the data, starting from 'TrialStart' to subjects 'Response'
        trialData = ascDf.loc[indexStart:indexEnd]
        trialData['subjectID'] = subjectIntId.astype(int)
        trialData['runtrial'] = trial+1
        mergeData = pd.merge(txtData, trialData)
        if(trial+1 == 1):
            allTrialsData = pd.DataFrame(columns = mergeData.columns)
        allTrialsData = pd.concat([allTrialsData,mergeData])
        print('Log.....'+'Trial'+str(trial+1).zfill(3))
    
    #Appending all data to one DataFrame
    if flag == 0:
        allSubjectsData = pd.DataFrame(columns = allTrialsData.columns)
        flag = 1
    allSubjectsData = pd.concat([allSubjectsData,allTrialsData])
    
# Rename columns if needed
#allSubjectsData.columns = ['subjectID','trialNum','onsettime','stimName','bid','RT','stimType','stimId',
#                         'timeStamp','X_axis','Y_axis' ]
# Out:
# Log.....Getting Ascii file data - MRI_faces_149_Probe_EyeTracking_block_2_run_1_19-Feb-2017_16h29m.asc
# Log.....Getting txt file data for subject id - 149
# Log.....Runing over all trials of subject id - 149
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-cdff9a54cbfe> in <module>()
#      48     #Appending all data to one DataFrame
#      49     if flag == 0:
# ---> 50         allSubjectsData = pd.DataFrame(columns = allTrialsData.columns)
#      51         flag = 1
#      52     allSubjectsData = pd.concat([allSubjectsData,allTrialsData])
#
# NameError: name 'allTrialsData' is not defined

# %%
allSubjectsData
# Out:
#            subjectID trialNum    onsettime              stimName       bid  \
# 0     bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 1     bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 2     bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 3     bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 4     bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 5     bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 6     bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 7     bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 8     bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 9     bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 10    bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 11    bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 12    bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 13    bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 14    bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 15    bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 16    bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 17    bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 18    bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 19    bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 20    bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 21    bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 22    bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 23    bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 24    bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 25    bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 26    bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 27    bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 28    bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# 29    bmem_short_116        1     0.087863  309_katz_yisrael.jpg  3.006653
# ...              ...      ...          ...                   ...       ...
# 971   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 972   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 973   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 974   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 975   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 976   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 977   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 978   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 979   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 980   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 981   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 982   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 983   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 984   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 985   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 986   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 987   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 988   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 989   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 990   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 991   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 992   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 993   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 994   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 995   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 996   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 997   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 998   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 999   bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
# 1000  bmem_short_143      180  1169.429000   210_mofaz_shaul.jpg  5.598816
#
#             RT       stimType stimId timeStamp   X_axis   Y_axis
# 0     3.661447  FamiliarFaces      6    262782    979.7    549.0
# 1     3.661447  FamiliarFaces      6    262786    978.6    548.8
# 2     3.661447  FamiliarFaces      6    262790    978.0    548.8
# 3     3.661447  FamiliarFaces      6    262794    978.0    548.8
# 4     3.661447  FamiliarFaces      6    262798    978.1    548.8
# 5     3.661447  FamiliarFaces      6    262802    978.1    548.6
# 6     3.661447  FamiliarFaces      6    262806    978.1    548.5
# 7     3.661447  FamiliarFaces      6    262810    978.0    548.3
# 8     3.661447  FamiliarFaces      6    262814    978.0    548.0
# 9     3.661447  FamiliarFaces      6    262818    978.0    547.7
# 10    3.661447  FamiliarFaces      6    262822    978.4    547.5
# 11    3.661447  FamiliarFaces      6    262826    978.8    547.5
# 12    3.661447  FamiliarFaces      6    262830    979.1    547.8
# 13    3.661447  FamiliarFaces      6    262834    979.3    548.4
# 14    3.661447  FamiliarFaces      6    262838    979.5    549.0
# 15    3.661447  FamiliarFaces      6    262842    979.6    549.5
# 16    3.661447  FamiliarFaces      6    262846    979.7    549.6
# 17    3.661447  FamiliarFaces      6    262850    979.6    549.7
# 18    3.661447  FamiliarFaces      6    262854    979.4    549.7
# 19    3.661447  FamiliarFaces      6    262858    979.2    549.8
# 20    3.661447  FamiliarFaces      6    262862    979.1    549.8
# 21    3.661447  FamiliarFaces      6    262866    979.5    549.7
# 22    3.661447  FamiliarFaces      6    262870    980.0    549.4
# 23    3.661447  FamiliarFaces      6    262874    980.6    549.1
# 24    3.661447  FamiliarFaces      6    262878    980.9    549.1
# 25    3.661447  FamiliarFaces      6    262882    981.0    549.2
# 26    3.661447  FamiliarFaces      6    262886    980.9    549.5
# 27    3.661447  FamiliarFaces      6    262890    980.8    549.9
# 28    3.661447  FamiliarFaces      6    262894    980.6    550.3
# 29    3.661447  FamiliarFaces      6    262898    980.5    550.7
# ...        ...            ...    ...       ...      ...      ...
# 971   3.275996  FamiliarFaces      6   5188076        .        .
# 972   3.275996  FamiliarFaces      6   5188078        .        .
# 973   3.275996  FamiliarFaces      6   5188080        .        .
# 974   3.275996  FamiliarFaces      6   5188082        .        .
# 975   3.275996  FamiliarFaces      6   5188084        .        .
# 976   3.275996  FamiliarFaces      6   5188086        .        .
# 977   3.275996  FamiliarFaces      6   5188088        .        .
# 978   3.275996  FamiliarFaces      6   5188090        .        .
# 979   3.275996  FamiliarFaces      6   5188092        .        .
# 980   3.275996  FamiliarFaces      6   5188094        .        .
# 981   3.275996  FamiliarFaces      6   5188096        .        .
# 982   3.275996  FamiliarFaces      6   5188098        .        .
# 983   3.275996  FamiliarFaces      6   5188100        .        .
# 984   3.275996  FamiliarFaces      6   5188102        .        .
# 985   3.275996  FamiliarFaces      6   5188104        .        .
# 986   3.275996  FamiliarFaces      6   5188106        .        .
# 987   3.275996  FamiliarFaces      6   5188108        .        .
# 988   3.275996  FamiliarFaces      6   5188110        .        .
# 989   3.275996  FamiliarFaces      6   5188112        .        .
# 990   3.275996  FamiliarFaces      6   5188114        .        .
# 991   3.275996  FamiliarFaces      6   5188116        .        .
# 992   3.275996  FamiliarFaces      6   5188118        .        .
# 993   3.275996  FamiliarFaces      6   5188120        .        .
# 994   3.275996  FamiliarFaces      6   5188122        .        .
# 995   3.275996  FamiliarFaces      6   5188124        .        .
# 996   3.275996  FamiliarFaces      6   5188126        .        .
# 997   3.275996  FamiliarFaces      6   5188128        .        .
# 998   3.275996  FamiliarFaces      6   5188130        .        .
# 999   3.275996  FamiliarFaces      6   5188132        .        .
# 1000  3.275996  FamiliarFaces      6   5188134        .        .
#
# [2944520 rows x 11 columns]

# %% [markdown]
# # DF to pickle

# %%
#Store all subjects data DF as pikle
allSubjectsData.to_pickle('scale_ranking_bmm_short_data')

# %%
#Read pikle into DF
file_name = 'scale_ranking_bmm_short_data'
df = pd.read_pickle(file_name)
